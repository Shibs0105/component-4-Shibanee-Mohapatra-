# %%
import attrition_by_recruiting_source_plot
# Out:
# C:\Users\KIIT0001\data analyst new\attrition_by_recruiting_source_plot.py:15: FutureWarning: Using print(plot) to draw and show the plot figure is deprecated and will be removed in a future version. Use plot.show().

# %%
import sales_by_recruiting_source_plot
# Out:
#    attrition  performance_rating  sales_quota_pct recruiting_source
# 0          1                   3         1.088190    Applied Online
# 1          0                   3         2.394173               NaN
# 2          1                   2         0.497530            Campus
# 3          0                   2         2.513958               NaN
# 4          0                   3         1.424789    Applied Online
